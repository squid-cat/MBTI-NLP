# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import plotly.express as px
import re

warnings.filterwarnings('ignore')

# %%
data1 = pd.read_csv('./data/csv/mbti_1.csv')
data2 = pd.read_csv('./data/csv/MBTI_500.csv')
datas = pd.concat([data1, data2])

# %%
data1.describe(include='O')
# Out:
#         type                                              posts
# count   8675                                               8675
# unique    16                                               8675
# top     INFP  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# freq    1832                                                  1

# %%
data2.describe(include='O')
# Out:
#                                                     posts    type
# count                                              106067  106067
# unique                                             106067      16
# top     know intj tool use interaction people excuse a...    INTP
# freq                                                    1   24961

# %%
datas.describe(include='O')
# Out:
#           type                                              posts
# count   114742                                             114742
# unique      16                                             114742
# top       INTP  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# freq     26265                                                  1

# %%
data1['type'].value_counts()
# Out:
# INFP    1832
# INFJ    1470
# INTP    1304
# INTJ    1091
# ENTP     685
# ENFP     675
# ISTP     337
# ISFP     271
# ENTJ     231
# ISTJ     205
# ENFJ     190
# ISFJ     166
# ESTP      89
# ESFP      48
# ESFJ      42
# ESTJ      39
# Name: type, dtype: int64

# %%
data2['type'].value_counts()
# Out:
# INTP    24961
# INTJ    22427
# INFJ    14963
# INFP    12134
# ENTP    11725
# ENFP     6167
# ISTP     3424
# ENTJ     2955
# ESTP     1986
# ENFJ     1534
# ISTJ     1243
# ISFP      875
# ISFJ      650
# ESTJ      482
# ESFP      360
# ESFJ      181
# Name: type, dtype: int64

# %%
datas['type'].value_counts()
# Out:
# INTP    26265
# INTJ    23518
# INFJ    16433
# INFP    13966
# ENTP    12410
# ENFP     6842
# ISTP     3761
# ENTJ     3186
# ESTP     2075
# ENFJ     1724
# ISTJ     1448
# ISFP     1146
# ISFJ      816
# ESTJ      521
# ESFP      408
# ESFJ      223
# Name: type, dtype: int64

# %%
px.pie(datas, names='type', title='Personality type',hole=0.5)

# %%
# wards count
counts = dict()
for v in datas['posts']:
  count = len(v)
  counts[count] = counts.get(count, 0) + 1

lst_display = list()
for i in range(max(counts)):
  lst_display.append(counts.get(i, 0))

plt.figure(figsize=(20,10))
plt.plot(lst_display)
plt.xlim(0, max(counts))
plt.ylim(0)
plt.title('(BEFORE) Number of words in text',fontdict={'size':20,'style':'italic'})
plt.show()
